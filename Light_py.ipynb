# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1Nz2WGtW7Ip76rmStiX6")
project = rf.workspace().project("lightproject")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to LightProject-1 in yolov5pytorch:: 100%|███████████| 254/254 [00:00<00:00, 632.66it/s]

# %%
# %cd ../yolov5
# Out:
# E:\Develop\conda\yolov5

# %%
pwd
# Out:
# 'E:\\Develop\\conda\\yolov5'

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom

# Images
img = 'https://ultralytics.com/images/zidane.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov5_master
# C:\Users\User\anaconda3\envs\myai\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# requirements: YOLOv5 requirement "scipy>=1.4.1" not found, attempting AutoUpdate...
# ...
#   Using cached numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.1
#     Uninstalling numpy-1.23.1:
#       Successfully uninstalled numpy-1.23.1
# ...
#
# requirements: 1 package updated per C:\Users\User\.cache\torch\hub\ultralytics_yolov5_master\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2022-9-23 Python-3.9.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# ...

# %%
import matplotlib.pyplot as plt

# %%
# !python detect.py --source data/images/ --weights yolov5s.pt
# Out:
# detect: weights=['yolov5s.pt'], source=data/images/, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-155-g489920a Python-3.9.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 E:\Develop\conda\yolov5\data\images\bus.jpg: 640x480 4 persons, 1 bus, 11.0ms
# image 2/2 E:\Develop\conda\yolov5\data\images\zidane.jpg: 384x640 2 persons, 2 ties, 10.2ms
# Speed: 0.5ms pre-process, 10.6ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp6

# %%
# %cd ../
# Out:
# E:\Develop\conda

# %%
# %cd Light_project/yolov5
# Out:
# E:\Develop\conda\Light_project\yolov5

# %%
# %pwd
# Out:
# 'E:\\Develop\\conda\\Light_project\\yolov5'

# %%
# !python train.py --img 512 --batch 3 --epochs 20 --data LightProject-1/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=LightProject-1/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=20, batch_size=3, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 40 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.2-155-g489920a Python-3.9.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
#
# ...

# %%
pwd
# Out:
# 'E:\\Develop\\conda\\Light_project\\yolov5'

# %%
# %cd E:\Develop\conda\Light_project\yolov5
# Out:
# E:\Develop\conda\Light_project\yolov5

# %%
pwd
# Out:
# 'E:\\Develop\\conda\\Light_project\\yolov5'

# %%
# %cp ./runs/train/exp6/weights/best.pt ../models/
# Out:
# UsageError: Line magic function `%cp` not found.

# %%
# !python detect.py --source LightProject-1/test/images/img_30_jpg.rf.6a86300924000970af8c356b4c70dc13.jpg --weights ../models/best.pt
# Out:
# detect: weights=['../models/best.pt'], source=LightProject-1/test/images/img_30_jpg.rf.6a86300924000970af8c356b4c70dc13.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-155-g489920a Python-3.9.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 E:\Develop\conda\Light_project\yolov5\LightProject-1\test\images\img_30_jpg.rf.6a86300924000970af8c356b4c70dc13.jpg: 640x640 (no detections), 6.5ms
# Speed: 0.0ms pre-process, 6.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# !python detect.py --source LightProject-1/test/images/img_39_jpg.rf.dd7628217a16685dab45473e3b3e349b.jpg --weights ../models/best.pt
# Out:
# detect: weights=['../models/best.pt'], source=LightProject-1/test/images/img_39_jpg.rf.dd7628217a16685dab45473e3b3e349b.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v6.2-155-g489920a Python-3.9.5 torch-1.12.1 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 8192MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 E:\Develop\conda\Light_project\yolov5\LightProject-1\test\images\img_39_jpg.rf.dd7628217a16685dab45473e3b3e349b.jpg: 640x640 (no detections), 8.0ms
# Speed: 0.0ms pre-process, 8.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# ...
